# %% [markdown]
# # Álgebra Relacional - OpenClass IDP

# %% [markdown]
# ## Series

# %%
# Importe a biblioteca pandas
import pandas as pd

# %% [markdown]
# ### Crie um objeto Series

# %%
# Crie uma Serie contendo os seguintes elementos [4, 7, -5, 3]
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
# Crie um objeto Series contendo [4, 7, -5, 3] e 
#   defina seu próprio array de índices como sendo ['d', 'b', 'a', 'c']
obj2 = pd.Series([4, 7, -5, 3, 'a'], index=['d', 'b', 'a', 'c', 'f'])
obj2
# Out:
# d     4
# b     7
# a    -5
# c     3
# f     a
# dtype: object

# %% [markdown]
# ### Use o índice para acessar o valor

# %%
# Retorne o elemento de índice a
obj2['a']
# Out:
# -5

# %%
# Atribua o valor 6 ao elemento de índice d
obj2['d'] = 6
obj2
# Out:
# d     6
# b     7
# a    -5
# c     3
# f     a
# dtype: object

# %%
# Retorne os valores de índice 'c', 'a' e 'd'
obj2[['c', 'a', 'd']]
# Out:
# c     3
# a    -5
# d     6
# dtype: object

# %% [markdown]
# ### Criando uma Serie com um dicionário

# %%
# Crie uma série como seguinte dicionário 
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# ### Criando uma Serie com um dicionário
# #### mas especificando seu próprio índice separadamente

# %%
# Crie uma série como seguinte dicionário 
# sdata= {'Ohio': 35000, 'Texas': 71000, 'Oregon': None, 'Utah': None}
# mas especificando como índice este vetor ['California', 'Ohio', 'Oregon', 'Texas']
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %% [markdown]
# ### Aritmética com Series
# #### Automaticamente alinha os valores pelo índice

# %%
# Operações com indexação automática simplificam a sintaxe e a lógica de programação
# Some as séries criadas nos dois exercícios anteriores (obj3 e obj4)
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %% [markdown]
# ### Equivalente com dicionário

# %%
# + Linhas de código, + Tempo/Custo, + Possibilidade de erros
from numpy import nan 
dic3 = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
dic4 = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'California': nan}
result = dic3.copy()
for k4, v4 in dic4.items():
  if k4 in result.keys():
    result[k4] += v4
  else:
    result[k4] = v4
print(result)
# Out:
# {'Ohio': 70000, 'Texas': 142000, 'Oregon': 32000, 'Utah': 5000, 'California': nan}

# %% [markdown]
# ## DataFrame

# %%
# Crie um data frame a partir dos dados do seguinte dicionário, chame-o de frame
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# ### Mostre as primeiras linhas de um DataFrame

# %%
# Acesse as primeiras linhas do dataframe
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %% [markdown]
# ### Uma coluna pode ser recuperada como uma Serie
# #### A notação .nome_coluna não funciona quando o nome da coluna contém espaços
# ### Acostume-se a usar a notação ['nome_coluna']

# %%
# Acesse a coluna state usando a sintaxe com colchetes
frame['state']
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
# Acesse a coluna year com a sintaxe .nome
frame.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %% [markdown]
# ### Colunas podem ser modificadas por atribuição
# #### Atribuição de um valor único ou de um array numpy

# %%
# Atribua o valor 16.5 para todas as posições da coluna debt
# Quando a coluna não existir, o pandas cria ela pra você
frame['debt'] = 16.5
frame
# Out:
#     state  year  pop  debt
# 0    Ohio  2000  1.5  16.5
# 1    Ohio  2001  1.7  16.5
# 2    Ohio  2002  3.6  16.5
# 3  Nevada  2001  2.4  16.5
# 4  Nevada  2002  2.9  16.5
# 5  Nevada  2003  3.2  16.5

# %%
# Atribua o valor de um intervalo de 0 a 5 (float) na coluna debt
frame['debt'] = np.arange(6.)
frame
# Out:
#     state  year  pop  debt
# 0    Ohio  2000  1.5   0.0
# 1    Ohio  2001  1.7   1.0
# 2    Ohio  2002  3.6   2.0
# 3  Nevada  2001  2.4   3.0
# 4  Nevada  2002  2.9   4.0
# 5  Nevada  2003  3.2   5.0

# %%
# Crie uma nova coluna chamada eastern com o valor True para 
#   as linhas cujo estado seja Ohio, e False caso contrário
frame['eastern'] = frame.state == 'Ohio'
frame
# Out:
#     state  year  pop  debt  eastern
# 0    Ohio  2000  1.5   0.0     True
# 1    Ohio  2001  1.7   1.0     True
# 2    Ohio  2002  3.6   2.0     True
# 3  Nevada  2001  2.4   3.0    False
# 4  Nevada  2002  2.9   4.0    False
# 5  Nevada  2003  3.2   5.0    False

# %% [markdown]
# Mais teoria e exemplos [aqui](https://github.com/alexlopespereira/minicursoIDP2021/tree/master/pandas).

# %% [markdown]
# ## Criando a tabela/dataframe de Clientes

# %%
# Exemplo com a tabela Cliente
dict_clintes = {'nro_cli': [1,2,3,4],
        'nome_cli': ['Márcia', 'Cristina', 'Manoel', 'Rodrigo'],
        'end_cli': ['Rua X', 'Avenida 1', 'Avenida 3', 'Rua X'],
        'saldo': [100, 10, 234, 137],
        'cod_vend': [1, 1, 1, 2]}
df_cliente = pd.DataFrame(dict_clintes)
df_cliente
# Out:
#    nro_cli  nome_cli    end_cli  saldo  cod_vend
# 0        1    Márcia      Rua X    100         1
# 1        2  Cristina  Avenida 1     10         1
# 2        3    Manoel  Avenida 3    234         1
# 3        4   Rodrigo      Rua X    137         2

# %% [markdown]
# ### Projeção

# %%
# Selecione as colunas nome_cli e end_cli
df_cliente[['nome_cli', 'end_cli']]
# Out:
#    nome_cli    end_cli
# 0    Márcia      Rua X
# 1  Cristina  Avenida 1
# 2    Manoel  Avenida 3
# 3   Rodrigo      Rua X

# %% [markdown]
# ### Seleção (filtro)

# %%
# Retorne as linhas do dataframe cujo valor da coluna three seja maior que 5
df_cliente[(df_cliente['nome_cli']=='Cristina') | (df_cliente['nome_cli']=='Manoel')]
#
# Out:
#    nro_cli  nome_cli    end_cli  saldo  cod_vend
# 1        2  Cristina  Avenida 1     10         1
# 2        3    Manoel  Avenida 3    234         1

# %%
(df_cliente['nome_cli']=='Cristina') | (df_cliente['nome_cli']=='Manoel')
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: nome_cli, dtype: bool

# %% [markdown]
# # Seção 1 de Exercícios

# %% [markdown]
# ### Considere o seguinte dataframe

# %%
data2 = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame2 = pd.DataFrame(data2)
frame2
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# ### Exercício 1.1
# #### Selecione os registros dos anos maiores ou iguais a 2001.

# %%
# Faça aqui
frame2['year'] >= 2001
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# Name: year, dtype: bool

# %%
frame2[frame2['year'] >= 2002]
# Out:
#     state  year  pop
# 2    Ohio  2002  3.6
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# ### Exercício 1.2
# A média dos valores de uma coluna pode ser calculada assim:
# `frame2['pop'].mean()`
#
# Selecione os registros cuja coluna pop seja maior do que a média

# %%
# Faça aqui
frame2['pop'] > frame2['pop'].mean()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# Name: pop, dtype: bool

# %%
frame2[frame2['pop'] > frame2['pop'].mean()]
# Out:
#     state  year  pop
# 2    Ohio  2002  3.6
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# ## Exercício 1.3
# ### Considerando o dataset Diamonds, escreva uma função para retornar as informações dos diamantes que atendam a especificação x > 7 e y > 7 e Z > 7
# #### Use o dataset Diamonds (https://www.kaggle.com/shivam2503/diamonds)
# #### Dica 1: Use o operador & (AND) para realizar a conjunção lógica (p ^ q). Use a sintaxe com colchete e parênteses df[(S1) & (S2) & (S3)]
#
# #### O código a seguir faz o download deste dataset

# %%
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Faça aqui

# diamonds[(diamonds['x']>7) & (S2) & (S3)]
regra = (diamonds['x']>6)&(diamonds['y']>6)&(diamonds['z']>6)

# %%
diamonds.loc[regra, ['price','x']]
# Out:
#        price      x
# 23644  11668   9.53
# 24067  12210   8.09
# 24328  12587   9.65
# 25998  15223  10.14
# 25999  15223  10.02
# 26194  15562   7.89
# 26431  15964   9.42
# 26444  15984  10.01
# 26534  16193   9.86
# 27130  17329  10.00
# 27415  18018  10.74
# 27630  18531  10.23
# 27679  18701   9.66

# %%
diamonds[regra]
# Out:
#        carat        cut color clarity  depth  table  price      x      y     z
# 23644   3.65       Fair     H      I1   67.1   53.0  11668   9.53   9.48  6.38
# 24067   2.00    Premium     H     SI2   58.9   57.0  12210   8.09  58.90  8.06
# 24328   3.50      Ideal     H      I1   62.8   57.0  12587   9.65   9.59  6.03
# 25998   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 25999   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 26194   2.01       Fair     G     SI2   65.6   56.0  15562   7.89   7.84  6.16
# 26431   3.40       Fair     D      I1   66.8   52.0  15964   9.42   9.34  6.27
# 26444   4.00  Very Good     I      I1   63.3   58.0  15984  10.01   9.94  6.31
# 26534   3.67    Premium     I      I1   62.4   56.0  16193   9.86   9.81  6.13
# 27130   4.13       Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27415   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# ...

# %% [markdown]
# ## Projeção e Seleção (Filtro) na mesma função com .loc
# ### Sintaxe: df.loc[ linhas, colunas ]
# ### Exemplos:

# %% [markdown]
# #### 1) Todas as linhas e a coluna nome_cli:

# %%
df_cliente.loc[ : , ['nome_cli']]
# Out:
#    nome_cli
# 0    Márcia
# 1  Cristina
# 2    Manoel
# 3   Rodrigo

# %% [markdown]
# #### 2) Clientes Cristina e Manoel, e colunas nome_cli e end_cli:

# %%
regra_cliente = (df_cliente['nome_cli']=='Cristina') | (df_cliente['nome_cli']=='Manoel')
regra_cliente
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: nome_cli, dtype: bool

# %%
colunas = ['nome_cli','end_cli']

# %%
df_cliente.loc[regra_cliente, colunas]
# Out:
#    nome_cli    end_cli
# 1  Cristina  Avenida 1
# 2    Manoel  Avenida 3

# %% [markdown]
# ### Projeção e Seleção (Filtro) com o Operador iloc
# #### Projeção/Seleção de linhas ou linhas e colunas

# %%
# Retorne o subconjunto especificado pela linha 2 e colunas 3, 0 e 1
df_cliente.iloc[[1,2], [2, 3]]
# Out:
#      end_cli  saldo
# 1  Avenida 1     10
# 2  Avenida 3    234

# %% [markdown]
# ### Outros exemplos de loc, iloc e []

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e', 'f'])
frame
# Out:
#     state  year  pop
# a    Ohio  2000  1.5
# b    Ohio  2001  1.7
# c    Ohio  2002  3.6
# d  Nevada  2001  2.4
# e  Nevada  2002  2.9
# f  Nevada  2003  3.2

# %% [markdown]
# ### merge (fundir/juntar)
# #### A chave de junção (identificador único) foi inferida a partir do contexto (procurando nas colunas)
# #### Também pode ser especificada com o argumento on (Ex.: on='key')

# %%
# Considere os seguintes DataFrames
df_medico = pd.DataFrame({'cpf': ['11222731642','91498733332','81464221612'], 
                    'nome': ['Jose Pereira', 'Maria da Silva', 'Pedro Martins'], 
                    'Salario': [10, 20, 15]})
df_professor = pd.DataFrame({'cpf': ['11222731642','91498733332','21564281600'], 
                    'nome': ['Jose Pereira', 'Maria da Silva', 'Roberto Afonso'], 
                    'Salario': [6, 8, 5]})

# %%
# Mostre o dataframe df1
df_medico
# Out:
#            cpf            nome  Salario
# 0  11222731642    Jose Pereira       10
# 1  91498733332  Maria da Silva       20
# 2  81464221612   Pedro Martins       15

# %%
# Mostre o dataframe df2
df_professor
# Out:
#            cpf            nome  Salario
# 0  11222731642    Jose Pereira        6
# 1  91498733332  Maria da Silva        8
# 2  21564281600  Roberto Afonso        5

# %%
# Faça o merge dos dois dataframes usando como chave de junção a coluna 'key'
# O parametro on neste caso é redundante. Funcionaria sem ele.
pd.merge(df_medico, df_professor, on='cpf', suffixes=['_M','_P'])

# Por que chamamos esse tipo de merge/join de inner ? R.: Porque ele considera apenas a 
#     intersecção dos dois conjuntos de chaves.
# O argumento how='inner' é o padrão.
# Out:
#            cpf          nome_M  Salario_M          nome_P  Salario_P
# 0  11222731642    Jose Pereira         10    Jose Pereira          6
# 1  91498733332  Maria da Silva         20  Maria da Silva          8

# %%
# Faça também o merge com o argumento how='outer'
pd.merge(df_medico, df_professor, how='outer')
# Out:
#            cpf            nome  Salario
# 0  11222731642    Jose Pereira       10
# 1  91498733332  Maria da Silva       20
# 2  81464221612   Pedro Martins       15
# 3  11222731642    Jose Pereira        6
# 4  91498733332  Maria da Silva        8
# 5  21564281600  Roberto Afonso        5

# %% [markdown]
# ### Validando a cardinalidade do merge

# %%
left = pd.DataFrame({"A": [1, 2], "B": [1, 2]})
right = pd.DataFrame({"A": [4, 5, 6], "B": [2, 2, 2]})
print("DF Left")
print(right)
print("\nDF Right")
print(left)
# Out:
# DF Left
#    A  B
# 0  4  2
# 1  5  2
# 2  6  2
#
# DF Right
#    A  B
# 0  1  1
# 1  2  2

# %%
pd.merge(left, right, on="B", how="outer", validate="1:1")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-107-cd3783b32caa> in <module>()
# ----> 1 pd.merge(left, right, on="B", how="outer", validate="1:1")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     660         # are in fact unique.
#     661         if validate is not None:
# --> 662             self._validate(validate)
#     663
# ...

# %% [markdown]
# ### join (fundir/juntar)
# #### Semelhante ao merge, mas a chave de junção é o índice do DataFrame

# %%
# Considere os seguintes DataFrames
left2 = pd.DataFrame([[1., 2.], [3., 4.], [5., 6.]], index=['a', 'c', 'e'], 
                     columns=['Ohio', 'Nevada'])
right2 = pd.DataFrame([[7., 8.], [9., 10.], [11., 12.], [13, 14]],index=['b', 'c', 'd', 'e'],
                     columns=['Missouri', 'Alabama'])

# %%
# Mostre o dataframe left2
left2
# Out:
#    Ohio  Nevada
# a   1.0     2.0
# c   3.0     4.0
# e   5.0     6.0

# %%
# Mostre o dataframe right2
right2
# Out:
#    Missouri  Alabama
# b       7.0      8.0
# c       9.0     10.0
# d      11.0     12.0
# e      13.0     14.0

# %%
# Faça o join entre os dois DataFrames sem descartar registros que não estejam 
#      nos dois DataFrames
left2.join(right2, how='outer')
# Out:
#    Ohio  Nevada  Missouri  Alabama
# a   1.0     2.0       NaN      NaN
# b   NaN     NaN       7.0      8.0
# c   3.0     4.0       9.0     10.0
# d   NaN     NaN      11.0     12.0
# e   5.0     6.0      13.0     14.0

# %%
# Considerando os dataframes left2 e right2 definidos acima
# Faça o join entre os dois DataFrames sem descartar registros que estejam 
# apenas no dataframe left2, e descartando registros que estejam apenas no right2
left2.join(right2, how='left')
# Out:
#    Ohio  Nevada  Missouri  Alabama
# a   1.0     2.0       NaN      NaN
# c   3.0     4.0       9.0     10.0
# e   5.0     6.0      13.0     14.0

# %% [markdown]
# # Seção 2 de Exercícios

# %% [markdown]
# ### Considere os seguintes dataframes

# %%
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'], 'data1': range(7)})
df2 = pd.DataFrame({'key': ['a', 'b', 'd'], 'data2': range(3)})

# %%
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %% [markdown]
# ## Exercício 2.1
# ### Crie um inner join desses dois dataframes

# %%
# Faça aqui
df1.merge(df2, how='inner')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %% [markdown]
# ## Exercício 2.2
# ### Valide se este merge/join obedece uma cardinalidade 1:1

# %%
# Faça aqui

# %%
df1.merge(df2, how='inner', validate='m:1')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0
